# %% [markdown]
# # Settings

# %% [raw]
# http://localhost:8890/lab!pip install textblob
# !pip install vaderSentiment
# !pip install nltk
# !pip install opendatasets

# %% [markdown]
# ## Imports

# %%
import sys,tweepy,csv,re, requests, json
import matplotlib.pyplot as plt
from dotenv import dotenv_values
import pandas as pd
import numpy as np
import os, time, re


from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textblob import TextBlob

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

import string
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/gustavo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Configs

# %%
import warnings

# Suppressing the warnings
warnings.filterwarnings('ignore') 

#Changing dir
folder = 'ML'
try:
    os.chdir(f'{os.getcwd()}/{folder}')
except:
    dir = os.getcwd().replace(os.getcwd().split('/')[-1], folder)
    os.chdir(dir)

# %% [markdown]
# # Getting Twitter

# %% [markdown]
# ## API

# %%
#token
config = dotenv_values(".env")
bearer_token = config['BEARER_TOKEN']

#connections
auth = tweepy.OAuth2BearerHandler({bearer_token})
api = tweepy.API(auth)




def bearer_oauth(r):
    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r

def connect_to_endpoint(url, params):
    response = requests.get(url, auth=bearer_oauth, params=params)
    #print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

def get_tweet_v1(query, max_n):
    search_url = 'https://api.twitter.com/2/tweets/search/recent'
    tweets_dt = pd.DataFrame()

    print(f'Getting tweets...')

    try:
        # Querying the API
        json_response = connect_to_endpoint(search_url, query)
        
        try:
            tweets_dt = pd.DataFrame.from_dict(json_response['data'])
            
            try:
                n_token = json_response['meta']["next_token"]
                n = 0
                while n_token != 0 | n < max_n:
                    print(f'Next Token: {n} \n {n_token}')
                    query_next = query
                    query_next['next_token'] = n_token
                    json_response = connect_to_endpoint(search_url, query_next)
                    tweets_n = pd.DataFrame.from_dict(json_response['data'])
                    tweets_dt = pd.concat([tweets_dt,tweets_n], ignore_index=True)

                    n += 1
                    n_token = json_response['meta']["next_token"]
                
            except:
                print('Error to get next page')
        
        except:
            print('Error to get data from Json File')     

    except:
        print('Error to querying API')
        
    return tweets_dt

# %% [markdown]
# ## Countries
#
# Getting up to 1000 tweets each country

# %%
countries = ['Austria', 'Belgium', 'Bulgaria', 'Cyprus', 'Czechia', 'Denmark', 'Finland', 'France', 'Germany', 'Hungary',
        'Ireland', 'Italy', 'Latvia', 'Netherlands', 'Poland', 'Portugal', 'Romania', 'Spain','Sweden', 'Europe', 'UK']

filename = 'tweets_agri_2k.bz2'

if os.path.exists(filename) == False: 
    for c in countries:

        q = {
        'query': f'agriculture {c} -is:retweet',
        'max_results': 100,
        'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
        'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
        'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
        'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
        }

        t = get_tweet_v1(q, 10)
        t['country'] = c
        if c == countries[0]:
            tweets = t
        else:
            tweets = pd.concat([tweets, t], ignore_index=True)

    tweets.to_csv(filename, index=False,compression='bz2')
    print(f'File with {len(tweets)} saved.')

else:
    create_dt = time.strftime("%d/%m/%Y %H:%M:%S",time.strptime(time.ctime(os.path.getmtime(filename))))
    print(f'Reading {filename}, created at {create_dt}')
    tweets = pd.read_csv(filename)
    print(f'File with {len(tweets)} Tweets')
    

tweets.sample()
# Out:
# Reading tweets_agri_2k.bz2, created at 06/01/2023 01:49:21
# File with 2126 Tweets
#                                          public_metrics      conversation_id  \
# 1416  {'retweet_count': 0, 'reply_count': 1, 'like_c...  1605285598478192663
#
#                                                    text reply_settings lang  \
# 1416  @tapyplus @zel_wur @KartapussFR @poti_posof @i...       everyone   fr
#
#        author_id   edit_history_tweet_ids                created_at  id  \
# 1416  2870270541  ['1605945871819948033']  2022-12-22T15:18:27.000Z NaN
#
#       in_reply_to_user_id                                  referenced_tweets  \
# 1416         1.474088e+18  [{'type': 'replied_to', 'id': '160594439984993...
#
#      country  geo
# 1416  France  NaN

# %% [markdown]
# # Clean Your Text Data

# %% [markdown]
# ## Worlds extractions

# %%
def clean_tweet(x, link, keyword, usernames):
    list_of_lists =[]
    if link == True:
        list_of_links = []
        words = x.split(' ')
        for word in words:
            if re.search('http', word):
                list_of_links.append(re.split("\W+",word.lower()))
        if len(list_of_links) > 0:
            list_of_lists.append(list_of_links[0])
    
    if keyword == True:
        list_of_keywords = []
        words = x.split()
        for word in words:
            if word.startswith('#'):
                list_of_keywords.append(word)
        if len(list_of_keywords) > 0:
            list_of_lists.append(list_of_keywords)
            
    if usernames == True:
        list_of_usernames = []
        words = x.split()
        for word in words:
            if word.startswith('@'):
                list_of_usernames.append(word.lower().replace('@',''))
        if len(list_of_usernames) > 0:
            list_of_lists.append(list_of_usernames)
    
    return  [item for sublist in list_of_lists for item in sublist]

        
# keyword extraction from tweets
def get_keywords(x):
    list_of_keywords = []
    words = x.split()
    for word in words:
        if word.startswith('#'):
            list_of_keywords.append(word)
    return list_of_keywords

# %%
tweets = tweets[tweets.lang == 'en']
tweets = tweets.reset_index(drop = True)

# %%
list_of_lists = tweets['text'].apply(lambda tweet : clean_tweet(tweet, link = True, keyword = False, usernames = True))
rem_list = [item for sublist in list_of_lists for item in sublist]

tweets['text_c'] = tweets['text'].apply( lambda tweet : ' '.join([word for word in re.split("\W+",tweet) if word.lower() not in rem_list]))

# %%
tweets['keywords'] = tweets['text'].apply( lambda tweet : get_keywords(tweet) )

# %%
tweets.sample(2)
# Out:
#                                         public_metrics      conversation_id  \
# 370  {'retweet_count': 168, 'reply_count': 5, 'like...  1610213417540882433
# 62   {'retweet_count': 0, 'reply_count': 0, 'like_c...  1609894654140616706
#
#                                                   text reply_settings lang  \
# 370  📢#HorizonEU 2023 Cluster 6 calls for proposals...       everyone   en
# 62   Cpec rpec projects 🌊💦 electric gas dam sugar s...       everyone   en
#
#                author_id   edit_history_tweet_ids                created_at  \
# 370           1372130516  ['1610213417540882433']  2023-01-03T09:56:09.000Z
# 62   1566407156576002050  ['1609894654140616706']  2023-01-02T12:49:30.000Z
#
#                id  in_reply_to_user_id referenced_tweets country  geo  \
# 370  1.610213e+18                  NaN               NaN  Europe  NaN
# 62   1.609895e+18                  NaN               NaN  France  NaN
#
#                                                 text_c  \
# 370  Cluster 6 calls for proposals open 890million ...
# 62   Cpec rpec projects electric gas dam sugar stee...
#
#                                               keywords
# 370  [#biodiversity,, #sustainable, #foodsystems,, ...
# 62                                                  []

# %%
n = 1
print('OLD: ', tweets['text'][n], '\n')
print('NEW: ', tweets['text_c'][n])
# Out:
# OLD:  @communistsusa Collectivization *destroyed* Czech agriculture and made it reliant on bootleg goods from Austria. Poland was spared from it due to Stalin's untimely death and is now one of Europe's largest producers. Only Central &amp; East Europeans know the real truth about communism.
#
# NEW:  Collectivization destroyed Czech made it reliant on bootleg goods from Austria Poland was spared from it due to Stalin s untimely death is one of s largest producers Only Central amp East Europeans know real truth about communism

# %% [markdown]
# ## PoterStemmer

# %%
# Store the stopwords into the object named as "stop_words"
stop_words = stopwords.words('english')

# Store the string.punctuation into an object punct
punct = string.punctuation

# Initialise an object using a method PorterStemmer
stemmer = PorterStemmer()

# %%
def stremming(df, text_col, name_new_col):
    # Store the column of the dataframe named as "text"
    X = df[text_col]
    cleaned_data=[]
    # For loop from first value to length(X), ^a-zA-Z means include small and capital case letters
    for i in range(len(X)):
        text = re.sub('[^a-zA-Z]', ' ', X.iloc[i])
        text = text.lower().split()
        text = [stemmer.stem(word) for word in text if (word not in stop_words) and (word not in punct)]
        text = ' '.join(text)
        df.loc[ i ,name_new_col] = text
    print('Stremmer done!')

# %%
stremming(tweets, 'text_c', 'text_ps')
# Out:
# Stremmer done!

# %%
print(tweets['text'][0], '\n')
print(tweets['text_ps'][0], '\n')
# Out:
# Academic spam is great! I've been invited to be a keynote speaker at a Plant Biology conference in Vienna 😂
# 95% sure it's spam, but tempted to say yes! Imagine it's legit and I find myself in Austria, speaking to a room of stunned plant experts about WWII Scottish agriculture...
#
# academ spam great invit keynot speaker plant biolog confer vienna sure spam tempt say ye imagin legit austria speak room stun plant expert wwii scottish

# %% [markdown]
# ## Sentiment Analyzes

# %% [markdown]
# TextBlob is a Python (2 and 3) library for processing textual data. It provides a simple API for diving into common natural language processing (NLP) tasks such as part-of-speech tagging, noun phrase extraction, sentiment analysis, classification, translation, and more. [link](https://textblob.readthedocs.io/en/dev/index.html)

# %%
tweets.sample(2)
# Out:
#                                         public_metrics      conversation_id  \
# 812  {'retweet_count': 0, 'reply_count': 1, 'like_c...  1605804819037528064
# 796  {'retweet_count': 0, 'reply_count': 0, 'like_c...  1605995232138510362
#
#                                                   text reply_settings lang  \
# 812  @JohnTiter9 @BillAckman @Ukraine It prevents R...       everyone   en
# 796  European Research Executive Agency (REA) annou...       everyone   en
#
#                author_id   edit_history_tweet_ids                created_at  \
# 812  1109480404703023104  ['1605815497051840512']  2022-12-22T06:40:23.000Z
# 796           3337809892  ['1605995232138510362']  2022-12-22T18:34:35.000Z
#
#      id  in_reply_to_user_id  \
# 812 NaN         1.227381e+18
# 796 NaN                  NaN
#
#                                      referenced_tweets country  geo  \
# 812  [{'type': 'replied_to', 'id': '160580689452577...  Europe  NaN
# 796                                                NaN  Europe  NaN
#
#                                                 text_c  \
# 812  It prevents Russia from dominating entire econ...
# 796  European Research Executive Agency REA announc...
#
#                                               keywords  \
# 812                                                 []
# 796  [#Cluster, #HorizonEurope, #Food,, #bioeconomy...
#
#                                                text_ps
# 812  prevent russia domin entir economi natur resou...
# 796  european research execut agenc rea announc clu...

# %%
for i in tweets.index:
    text = tweets.loc[i,'text_ps']
    tweets.loc[i, 'TextBlob'] = TextBlob(text).sentiment.polarity
    #print(TextBlob(text).sentiment.polarity)
    tweets.loc[i, 'Vader'] = SentimentIntensityAnalyzer().polarity_scores(text)['compound']
    #print(SentimentIntensityAnalyzer().polarity_scores(text)['compound'], '\n')
    
tweets.sample(2)
# Out:
#                                          public_metrics      conversation_id  \
# 331   {'retweet_count': 0, 'reply_count': 0, 'like_c...  1610574756792733697
# 1280  {'retweet_count': 1, 'reply_count': 0, 'like_c...  1604902419900600321
#
#                                                    text reply_settings lang  \
# 331   @J3Lyon I'm still to visit every country in Eu...       everyone   en
# 1280  @InnovelecSolut1, the UK agent for @emlid. Eml...       everyone   en
#
#        author_id   edit_history_tweet_ids                created_at  \
# 331   1296811382  ['1610792984769073152']  2023-01-05T00:19:09.000Z
# 1280   213802926  ['1604902419900600321']  2022-12-19T18:12:09.000Z
#
#                 id  in_reply_to_user_id  \
# 331   1.610793e+18         1.841978e+07
# 1280           NaN         3.292897e+09
#
#                                       referenced_tweets country  geo  \
# 331   [{'type': 'replied_to', 'id': '161077176956403...  Europe  NaN
# 1280                                                NaN      UK  NaN
#
#                                                  text_c    keywords  \
# 331   I m still to every country in but I learned de...          []
# 1280  InnovelecSolut1 agent for emlid Emlid design a...  [#LAMMA23]
#
#                                                 text_ps  TextBlob   Vader
# 331   still everi countri learn detail knowledg moun...       0.0 -0.2960
# 1280  innovelecsolut agent emlid emlid design afford...       0.0  0.4215

# %%
def get_polarity(df, col):

    polarity = 0
    neutral = 0
    wpositive = 0
    positive = 0
    spositive = 0
    wnegative = 0
    negative = 0
    snegative = 0
     
    for t in df.index:
        
        v = df.loc[t, col]
        polarity += v  # adding up polarities to find the average later

        if (v == 0):  # adding reaction of how people are reacting to find average later
            neutral += 1
            desc = 'neutral'
        elif (v > 0 and v <= 0.3):
            wpositive += 1
            desc ='weak_positive'
        elif (v > 0.3 and v <= 0.6):
            positive += 1
            desc = 'positive'
        elif (v > 0.6 and v <= 1):
            spositive += 1
            desc = 'strong_positive'
        elif (v > -0.3 and v <= 0):
            wnegative += 1
            desc = 'weak_negative'
        elif (v > -0.6 and v <= -0.3):
            negative += 1
            desc = 'negative'
        elif (v > -1 and v <= -0.6):
            snegative += 1
            desc = 'strong_negative'
         
        df.loc[t, f'{col}_desc'] = desc
        

    return {'polarity_sum':polarity,
            'polarity_mean':(polarity / len(df)),
            'neutral':neutral,
            'strong_positive':spositive,
            'positive':positive,
            'weak_positive':wpositive,
            'weak_negative':wnegative,
            'negative':negative,
            'strong_negative':snegative}

# %%
get_polarity(tweets,'TextBlob')
# Out:
# {'polarity_sum': 116.520942927443,
#  'polarity_mean': 0.08269761740769553,
#  'neutral': 557,
#  'strong_positive': 42,
#  'positive': 153,
#  'weak_positive': 430,
#  'weak_negative': 183,
#  'negative': 38,
#  'strong_negative': 4}

# %%
get_polarity(tweets,'Vader')
# Out:
# {'polarity_sum': 215.27659999999992,
#  'polarity_mean': 0.1527867991483321,
#  'neutral': 441,
#  'strong_positive': 206,
#  'positive': 355,
#  'weak_positive': 136,
#  'weak_negative': 87,
#  'negative': 121,
#  'strong_negative': 63}

# %%
tweets.sample()
# Out:
#                                         public_metrics      conversation_id  \
# 388  {'retweet_count': 141, 'reply_count': 19, 'lik...  1609845304970330112
#
#                                                   text reply_settings lang  \
# 388  "If the US is still ruthlessly protecting Micr...       everyone   en
#
#                author_id   edit_history_tweet_ids                created_at  \
# 388  1263789597563195394  ['1609845304970330112']  2023-01-02T09:33:24.000Z
#
#                id  in_reply_to_user_id referenced_tweets country  geo  \
# 388  1.609845e+18                  NaN               NaN  Europe  NaN
#
#                                                 text_c keywords  \
# 388  US is still ruthlessly protecting Microsoft Ap...       []
#
#                                                text_ps  TextBlob   Vader  \
# 388  us still ruthlessli protect microsoft appl hua...       0.0  0.3818
#
#     TextBlob_desc Vader_desc
# 388       neutral   positive

# %%
##Checking Twitters

n = 3
print('Text Original:', tweets.loc[n, 'text'], '\n',
     '-------------------------------------------------------------------------------------------')
print('Text Clear:', tweets.loc[n, 'text_c'], '\n',
     '-------------------------------------------------------------------------------------------')

print('Text Steammed:', tweets.loc[n, 'text_ps'], '\n',
     '-------------------------------------------------------------------------------------------')

print('KeyWords:', tweets.loc[n, 'keywords'], '\n',
     '-------------------------------------------------------------------------------------------')

print('TextBlob: ',tweets.loc[n, 'TextBlob'], tweets.loc[n, 'TextBlob_desc'])
print('Vader: ', tweets.loc[n, 'Vader'], tweets.loc[n, 'Vader_desc'])
# Out:
# Text Original: In coordination with #GOP &amp; through generous funding from #USAID, UN Central Emergency Fund, ECHO, &amp; Government of Japan &amp; Belgium, FAOPK Flood Emergency Response has supported hardest hit agriculture sub-sectors - #crop and #livestock
# @UNinPak @UNDP_Pakistan
# #ResilientPakistan https://t.co/iWQ0rRD1ah
#  -------------------------------------------------------------------------------------------
# Text Clear: In coordination with GOP amp through generous funding from USAID UN Central Emergency Fund ECHO amp Government of Japan amp Belgium FAOPK Flood Emergency Response has supported hardest hit sub sectors crop ResilientPakistan
#  -------------------------------------------------------------------------------------------
# Text Steammed: coordin gop amp gener fund usaid un central emerg fund echo amp govern japan amp belgium faopk flood emerg respons support hardest hit sub sector crop resilientpakistan
#  -------------------------------------------------------------------------------------------
# KeyWords: ['#GOP', '#USAID,', '#crop', '#livestock', '#ResilientPakistan']
#  -------------------------------------------------------------------------------------------
# TextBlob:  0.0 neutral
# Vader:  0.4019 positive

# %%
tweets.iloc[:, -6:]
# Out:
#                                                keywords  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [#GOP, #USAID,, #crop, #livestock, #ResilientP...
# 4     [#bednar, #bednarfmt, #joyoffarming, #kator, #...
# ...                                                 ...
# 1404                                                 []
# 1405                 [#BiggestJobonEarth, #agriculture]
# 1406                                                 []
# 1407                                                 []
# 1408  [#RemoteSensing, #ComputerScience, #hyperspect...
#
#                                                 text_ps  TextBlob   Vader  \
# 0     academ spam great invit keynot speaker plant b...  0.650000  0.3400
# 1     collectiv destroy czech made reliant bootleg g...  0.025000 -0.4019
# 2     jason hafemeist led deleg u stakehold collabor...  0.000000  0.0000
# 3     coordin gop amp gener fund usaid un central em...  0.000000  0.4019
# 4     larg amount potato grown prepar belgium bedar ...  0.000000  0.0000
# ...                                                 ...       ...     ...
# 1404  ye reform set safe amp legal rout refuge set n...  0.350000  0.8689
# 1405  case miss catch episod biggestjobonearth podca... -0.500000  0.1531
# 1406           respons contribut transform new strategi  0.136364  0.0000
# 1407                        eu minist call rethink free  0.400000  0.5106
# 1408  posit predict model hyperspectr satellit imag ...  0.000000  0.0000
#
#         TextBlob_desc       Vader_desc
# 0     strong_positive         positive
# 1       weak_positive         negative
# 2             neutral          neutral
# 3             neutral         positive
# 4             neutral          neutral
# ...               ...              ...
# 1404         positive  strong_positive
# 1405         negative    weak_positive
# 1406    weak_positive          neutral
# 1407         positive         positive
# 1408          neutral          neutral
#
# [1409 rows x 6 columns]

# %% [markdown]
# ## Sarcasm

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import learning_curve
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
news = pd.read_csv('sarcasm_headlines.bz2')
news.sample()
# Out:
#                                                 headline  is_sarcastic
# 19308  why christ, mao and the buddha are making a co...             0

# %%
print(news.isnull().any(axis = 0))
# Out:
# headline        False
# is_sarcastic    False
# dtype: bool

# %%
stremming(news, 'headline', 'headline_ps')
# Out:
# Stremmer done!

# %%
news.sample(2)
# Out:
#                                                 headline  is_sarcastic  \
# 5036   person cropped out of match.com picture clearl...             1
# 14443  elderly voter never thought she'd get to see f...             1
#
#                                              headline_ps
# 5036   person crop match com pictur clearli buzz ligh...
# 14443  elderli voter never thought get see femal pres...

# %%
def create_features(df, col, max_feat):
    features = df[col]

    # vectorizing the data with maximum features
    tv = TfidfVectorizer(max_features = max_feat)
    features = list(features)
    features = tv.fit_transform(features).toarray()
    
    return features

# %%
features = create_features(news, 'headline_ps', 5000)
labels = news['is_sarcastic']

# %%
# getting training and testing data
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size = 0.5, random_state = 0)

# %%
# %%time
print('\nLinear Support Vector Classifier:')
lsvc = LinearSVC()
lsvc.fit(features_train, labels_train)
print('Train: ',lsvc.score(features_train, labels_train))
print('Test: ',lsvc.score(features_test, labels_test))


print('\nGaussuan Naive Bayes:')
gnb = GaussianNB()
gnb.fit(features_train, labels_train)
print('Train: ',gnb.score(features_train, labels_train))
print('Test: ',gnb.score(features_test, labels_test))


print('\nLogistic Regression:')
lr = LogisticRegression()
lr.fit(features_train, labels_train)
print('Train: ',lr.score(features_train, labels_train))
print('Test: ',lr.score(features_test, labels_test))


print('\nRandom Forest Classifier:')
rfc = RandomForestClassifier(n_estimators = 10, random_state = 0)
rfc.fit(features_train, labels_train)
print('Train: ',rfc.score(features_train, labels_train))
print('Test: ',rfc.score(features_test, labels_test))
# Out:
# Linear Support Vector Classifier:
# Train:  0.9092406769507264
# Test:  0.7648820666417072
#
# Gaussuan Naive Bayes:
# Train:  0.7633667814886925
# Test:  0.6566080119805316
#
# Logistic Regression:
# Train:  0.8530777295192452
# Test:  0.7728940471733433
#
# Random Forest Classifier:
# Train:  0.9850980979481804
# Test:  0.7307375514788469
# CPU times: user 43.9 s, sys: 3.56 s, total: 47.5 s
# Wall time: 44.7 s

# %% [markdown]
# ### Cross-Validation

# %% [markdown]
# #### KFold

# %%
# %%time
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn import linear_model, tree, ensemble

kf =KFold(n_splits=5, shuffle=True, random_state=42)


print('\nLinear Support Vector Classifier:')
score = cross_val_score(lsvc, features, labels, cv= kf, scoring="accuracy")
print(f'Scores for each fold are: {score}')
print(f'Average score: {"{:.2f}".format(score.mean())}')


print('\nGaussuan Naive Bayes:')
score = cross_val_score(gnb, features, labels, cv= kf, scoring="accuracy")
print(f'Scores for each fold are: {score}')
print(f'Average score: {"{:.2f}".format(score.mean())}')


print('\nLogistic Regression:')
score = cross_val_score(lr, features, labels, cv= kf, scoring="accuracy")
print(f'Scores for each fold are: {score}')
print(f'Average score: {"{:.2f}".format(score.mean())}')


print('\nRandom Forest Classifier:')
score = cross_val_score(rfc, features, labels, cv= kf, scoring="accuracy")
print(f'Scores for each fold are: {score}')
print(f'Average score: {"{:.2f}".format(score.mean())}')
# Out:
# Linear Support Vector Classifier:
# Scores for each fold are: [0.77592662 0.79146387 0.77143392 0.78491202 0.77682082]
# Average score: 0.78
#
# Gaussuan Naive Bayes:
# Scores for each fold are: [0.68962935 0.68831898 0.66847623 0.68775739 0.68807339]
# Average score: 0.68
#
# Logistic Regression:
# Scores for each fold are: [0.785848   0.79801572 0.77873456 0.78172969 0.77925482]
# Average score: 0.78
#
# Random Forest Classifier:
# Scores for each fold are: [0.74653688 0.74728566 0.73867465 0.73567952 0.73993634]
# Average score: 0.74

# %% [markdown]
# ### Learning Curve

# %%
def get_learning_curve(model, X, y, cv, model_name):
    print(f'Getting Learning Curve for {model_name}')
    train_sizes, train_scores, test_scores = learning_curve(model, 
                                                            X, 
                                                            y, 
                                                            cv=cv, 
                                                            scoring='accuracy',
                                                            n_jobs=-1,
                                                            train_sizes=np.linspace(0.01, 1.0, 50))
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    print('Training Score:')
    print(f'Average: {"{:.2f}".format(train_scores.mean())}')
    print(f'Standard Deviation: {"{:.2f}".format(train_scores.std())}')

    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)
    print('\nTest Score:')
    print(f'Average: {"{:.2f}".format(test_scores.mean())}')
    print(f'Standard Deviation: {"{:.2f}".format(test_scores.std())}')
    
    print('\n')
    
    plt.subplots(1, figsize=(7,5))
    plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
    plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

    plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
    plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

    plt.title(f"Learning Curve for {model_name}")
    plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
    plt.tight_layout()
    plt.show()

# %%
# %%time
get_learning_curve(model = lsvc,
               X = features,
               y = labels,
               cv = kf,
               model_name = 'Linear Support Vector Classifier')
# Out:
# Getting Learning Curve for Linear Support Vector Classifier
# Training Score:
# Average: 0.94
# Standard Deviation: 0.04
#
# Test Score:
# Average: 0.74
# Standard Deviation: 0.04
# CPU times: user 1.41 s, sys: 2.15 s, total: 3.56 s
# Wall time: 3min 3s

# %%
# %%time
get_learning_curve(model = gnb,
               X = features,
               y = labels,
               cv = kf,
               model_name = 'Gaussuan Naive Bayes')

# %%
# %%time
get_learning_curve(model = lr,
               X = features,
               y = labels,
               cv = kf,
               model_name = 'Logistic Regression')

# %%
# %%time
get_learning_curve(model = rfc,
               X = features,
               y = labels,
               cv = kf,
               model_name = 'Random Forest Classifier')

# %% [markdown]
# ### Prev

# %%
prev = create_features(tweets, 'text_ps', 5000)

# %%
tweets['is_sarcastic_lsvc'] = lsvc.predict(prev)

# %%
tweets['is_sarcastic_lr'] = lr.predict(prev)

# %%
tweets.sample(4)
# Out:
#                                          public_metrics      conversation_id  \
# 580   {'retweet_count': 2, 'reply_count': 0, 'like_c...  1610421636339232773
# 573   {'retweet_count': 0, 'reply_count': 0, 'like_c...  1610207333589581824
# 168   {'retweet_count': 1, 'reply_count': 0, 'like_c...  1610329189818982401
# 1108  {'retweet_count': 1, 'reply_count': 0, 'like_c...  1605882660336898048
#
#                                                    text reply_settings lang  \
# 580   2023 is going to be a great year for #agtech a...       everyone   en
# 573   @andrew_lilico @northernmnkey @barthothingy Th...       everyone   en
# 168   TODAY: The Inhumane Society #AnimalWelfare #Fa...       everyone   en
# 1108  Circular systems in #agriculture Part 1: #Live...       everyone   en
#
#       author_id   edit_history_tweet_ids                created_at  \
# 580      805922  ['1610421636339232773']  2023-01-03T23:43:32.000Z
# 573   149636788  ['1610525321283121155']  2023-01-04T06:35:33.000Z
# 168   157075236  ['1610329189818982401']  2023-01-03T17:36:11.000Z
# 1108  143789185  ['1605882660336898048']  2022-12-22T11:07:16.000Z
#
#                 id  in_reply_to_user_id  ...  geo  \
# 580   1.610422e+18                  NaN  ...  NaN
# 573   1.610525e+18          149636788.0  ...  NaN
# 168   1.610329e+18                  NaN  ...  NaN
# 1108           NaN                  NaN  ...  NaN
#
#                                                  text_c  \
# 580   is going to be a great for agtech agrifood Dou...
# 573   leadership has aligned itself very strongly wi...
# 168   Inhumane Society AnimalWelfare FactoryFarms Pl...
# 1108  Circular in Part production sustainability b5s...
#
#                                                keywords  \
# 580   [#agtech, #agrifood., #Agritech, #agriculture,...
# 573                                                  []
# 168   [#AnimalWelfare, #FactoryFarms, #Plastic, #PFA...
# 1108                         [#agriculture, #Livestock]
#
#                                                 text_ps  TextBlob   Vader  \
# 580   go great agtech agrifood doubl operationalis a...  0.423377  0.8360
# 573   leadership align strongli leav think tank minf...  0.100000  0.0000
# 168   inhuman societi animalwelfar factoryfarm plast...  0.000000  0.4939
# 1108           circular part product sustain b sccqd pb  0.000000  0.0000
#
#       TextBlob_desc       Vader_desc is_sarcastic_lsvc is_sarcastic_lr
# 580        positive  strong_positive                 1               1
# 573   weak_positive          neutral                 0               0
# 168         neutral         positive                 1               0
# 1108        neutral          neutral                 0               0
#
# [4 rows x 22 columns]

# %%
##Checking Twitters

n = 1000
print('Text Original:', tweets.loc[n, 'text'], '\n',
     '-------------------------------------------------------------------------------------------')
print('Text Clear:', tweets.loc[n, 'text_c'], '\n',
     '-------------------------------------------------------------------------------------------')

print('Text Steammed:', tweets.loc[n, 'text_ps'], '\n',
     '-------------------------------------------------------------------------------------------')

print('KeyWords:', tweets.loc[n, 'keywords'], '\n',
     '-------------------------------------------------------------------------------------------')

print('TextBlob: ',tweets.loc[n, 'TextBlob'], tweets.loc[n, 'TextBlob_desc'])
print('Vader: ', tweets.loc[n, 'Vader'], tweets.loc[n, 'Vader_desc'])
print('Sarcasm (lsvc): ', tweets.loc[n, 'is_sarcastic_lsvc'])
print('Sarcasm (lr): ', tweets.loc[n, 'is_sarcastic_lr'])
# Out:
# Text Original: Live from Paris - Exclusive Fashion Designers -  LCT6D8M
#
# https://t.co/9y4qixCggn
#
# #Reverie #fox #Puck #Reality #summer #Realization #Aspiration #storage #Agriculture #Joanne #German #sweepstakes #Sleeper https://t.co/Co670OYh3L
#  -------------------------------------------------------------------------------------------
# Text Clear: Live from Paris Exclusive Fashion Designers fox Puck Reality summer Realization Aspiration storage Joanne German sweepstakes Sleeper Co670OYh3L
#  -------------------------------------------------------------------------------------------
# Text Steammed: live pari exclus fashion design fox puck realiti summer realiz aspir storag joann german sweepstak sleeper co oyh l
#  -------------------------------------------------------------------------------------------
# KeyWords: ['#Reverie', '#fox', '#Puck', '#Reality', '#summer', '#Realization', '#Aspiration', '#storage', '#Agriculture', '#Joanne', '#German', '#sweepstakes', '#Sleeper']
#  -------------------------------------------------------------------------------------------
# TextBlob:  0.06818181818181818 weak_positive
# Vader:  0.4588 positive
# Sarcasm (lsvc):  0
# Sarcasm (lr):  0
